# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread('./test_images/galtm.jpg')
img.shape
# Out:
# (455, 728, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (455, 728)

# %%
gray
# Out:
# array([[205, 204, 202, ...,  72,  67,  64],
#        [208, 206, 203, ...,  61,  57,  61],
#        [210, 208, 205, ...,  76,  82,  94],
#        ...,
#        [ 51,  49,  48, ...,  62,  60,  60],
#        [ 53,  51,  49, ...,  68,  67,  66],
#        [ 54,  52,  50, ...,  72,  71,  71]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[256,  59, 126, 126]])

# %%
(x,y,w,h)=faces[0]
x,y,w,h
# Out:
# (256, 59, 126, 126)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/galtm.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/galtm.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/galtm2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/galtm2.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/bale',
#  './dataset/gadot',
#  './dataset/keanu',
#  './dataset/Raina',
#  './dataset/Ronaldo']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# bale
# Generating cropped images in folder:  ./dataset/cropped/bale
# gadot
# Generating cropped images in folder:  ./dataset/cropped/gadot
# keanu
# Generating cropped images in folder:  ./dataset/cropped/keanu
# Raina
# Generating cropped images in folder:  ./dataset/cropped/Raina
# Ronaldo
# Generating cropped images in folder:  ./dataset/cropped/Ronaldo

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'bale': ['./dataset/cropped/bale/bale1.png',
#   './dataset/cropped/bale/bale2.png',
#   './dataset/cropped/bale/bale3.png',
#   './dataset/cropped/bale/bale4.png',
#   './dataset/cropped/bale/bale5.png',
#   './dataset/cropped/bale/bale6.png',
#   './dataset/cropped/bale/bale7.png',
#   './dataset/cropped/bale/bale8.png',
#   './dataset/cropped/bale/bale9.png',
#   './dataset/cropped/bale/bale10.png',
#   './dataset/cropped/bale/bale11.png',
#   './dataset/cropped/bale/bale12.png',
#   './dataset/cropped/bale/bale13.png',
#   './dataset/cropped/bale/bale14.png',
#   './dataset/cropped/bale/bale15.png',
#   './dataset/cropped/bale/bale16.png',
#   './dataset/cropped/bale/bale17.png',
#   './dataset/cropped/bale/bale18.png',
#   './dataset/cropped/bale/bale19.png',
#   './dataset/cropped/bale/bale20.png',
#   './dataset/cropped/bale/bale21.png',
#   './dataset/cropped/bale/bale22.png',
#   './dataset/cropped/bale/bale23.png',
#   './dataset/cropped/bale/bale24.png',
#   './dataset/cropped/bale/bale25.png',
#   './dataset/cropped/bale/bale26.png',
#   './dataset/cropped/bale/bale27.png',
#   './dataset/cropped/bale/bale28.png',
#   './dataset/cropped/bale/bale29.png',
#   './dataset/cropped/bale/bale30.png',
#   './dataset/cropped/bale/bale31.png',
#   './dataset/cropped/bale/bale32.png',
#   './dataset/cropped/bale/bale33.png',
#   './dataset/cropped/bale/bale34.png',
#   './dataset/cropped/bale/bale35.png',
#   './dataset/cropped/bale/bale36.png',
#   './dataset/cropped/bale/bale37.png',
#   './dataset/cropped/bale/bale38.png',
#   './dataset/cropped/bale/bale39.png',
#   './dataset/cropped/bale/bale40.png',
#   './dataset/cropped/bale/bale41.png',
#   './dataset/cropped/bale/bale42.png',
#   './dataset/cropped/bale/bale43.png',
#   './dataset/cropped/bale/bale44.png',
#   './dataset/cropped/bale/bale45.png',
#   './dataset/cropped/bale/bale46.png',
#   './dataset/cropped/bale/bale47.png',
#   './dataset/cropped/bale/bale48.png',
#   './dataset/cropped/bale/bale49.png',
#   './dataset/cropped/bale/bale50.png',
#   './dataset/cropped/bale/bale51.png',
#   './dataset/cropped/bale/bale52.png',
#   './dataset/cropped/bale/bale53.png',
#   './dataset/cropped/bale/bale54.png',
#   './dataset/cropped/bale/bale55.png',
#   './dataset/cropped/bale/bale56.png',
#   './dataset/cropped/bale/bale57.png',
#   './dataset/cropped/bale/bale58.png',
#   './dataset/cropped/bale/bale59.png'],
#  'gadot': ['./dataset/cropped/gadot/gadot1.png',
#   './dataset/cropped/gadot/gadot2.png',
#   './dataset/cropped/gadot/gadot3.png',
#   './dataset/cropped/gadot/gadot4.png',
#   './dataset/cropped/gadot/gadot5.png',
#   './dataset/cropped/gadot/gadot6.png',
#   './dataset/cropped/gadot/gadot7.png',
#   './dataset/cropped/gadot/gadot8.png',
#   './dataset/cropped/gadot/gadot9.png',
#   './dataset/cropped/gadot/gadot10.png',
#   './dataset/cropped/gadot/gadot11.png',
#   './dataset/cropped/gadot/gadot12.png',
#   './dataset/cropped/gadot/gadot13.png',
#   './dataset/cropped/gadot/gadot14.png',
#   './dataset/cropped/gadot/gadot15.png',
#   './dataset/cropped/gadot/gadot16.png',
#   './dataset/cropped/gadot/gadot17.png',
#   './dataset/cropped/gadot/gadot18.png',
#   './dataset/cropped/gadot/gadot19.png',
#   './dataset/cropped/gadot/gadot20.png',
#   './dataset/cropped/gadot/gadot21.png',
#   './dataset/cropped/gadot/gadot22.png',
#   './dataset/cropped/gadot/gadot23.png',
#   './dataset/cropped/gadot/gadot24.png',
#   './dataset/cropped/gadot/gadot25.png',
#   './dataset/cropped/gadot/gadot26.png',
#   './dataset/cropped/gadot/gadot27.png',
#   './dataset/cropped/gadot/gadot28.png',
#   './dataset/cropped/gadot/gadot29.png',
#   './dataset/cropped/gadot/gadot30.png',
#   './dataset/cropped/gadot/gadot31.png',
#   './dataset/cropped/gadot/gadot32.png',
#   './dataset/cropped/gadot/gadot33.png',
#   './dataset/cropped/gadot/gadot34.png',
#   './dataset/cropped/gadot/gadot35.png',
#   './dataset/cropped/gadot/gadot36.png',
#   './dataset/cropped/gadot/gadot37.png',
#   './dataset/cropped/gadot/gadot38.png',
#   './dataset/cropped/gadot/gadot39.png',
#   './dataset/cropped/gadot/gadot40.png',
#   './dataset/cropped/gadot/gadot41.png',
#   './dataset/cropped/gadot/gadot42.png',
#   './dataset/cropped/gadot/gadot43.png',
#   './dataset/cropped/gadot/gadot44.png',
#   './dataset/cropped/gadot/gadot45.png',
#   './dataset/cropped/gadot/gadot46.png',
#   './dataset/cropped/gadot/gadot47.png',
#   './dataset/cropped/gadot/gadot48.png',
#   './dataset/cropped/gadot/gadot49.png',
#   './dataset/cropped/gadot/gadot50.png',
#   './dataset/cropped/gadot/gadot51.png',
#   './dataset/cropped/gadot/gadot52.png',
#   './dataset/cropped/gadot/gadot53.png',
#   './dataset/cropped/gadot/gadot54.png',
#   './dataset/cropped/gadot/gadot55.png',
#   './dataset/cropped/gadot/gadot56.png',
#   './dataset/cropped/gadot/gadot57.png',
#   './dataset/cropped/gadot/gadot58.png',
#   './dataset/cropped/gadot/gadot59.png',
#   './dataset/cropped/gadot/gadot60.png',
#   './dataset/cropped/gadot/gadot61.png',
#   './dataset/cropped/gadot/gadot62.png',
#   './dataset/cropped/gadot/gadot63.png',
#   './dataset/cropped/gadot/gadot64.png',
#   './dataset/cropped/gadot/gadot65.png',
#   './dataset/cropped/gadot/gadot66.png',
#   './dataset/cropped/gadot/gadot67.png',
#   './dataset/cropped/gadot/gadot68.png',
#   './dataset/cropped/gadot/gadot69.png',
#   './dataset/cropped/gadot/gadot70.png',
#   './dataset/cropped/gadot/gadot71.png',
#   './dataset/cropped/gadot/gadot72.png'],
#  'keanu': ['./dataset/cropped/keanu/keanu1.png',
#   './dataset/cropped/keanu/keanu2.png',
#   './dataset/cropped/keanu/keanu3.png',
#   './dataset/cropped/keanu/keanu4.png',
#   './dataset/cropped/keanu/keanu5.png',
#   './dataset/cropped/keanu/keanu6.png',
#   './dataset/cropped/keanu/keanu7.png',
#   './dataset/cropped/keanu/keanu8.png',
#   './dataset/cropped/keanu/keanu9.png',
#   './dataset/cropped/keanu/keanu10.png',
#   './dataset/cropped/keanu/keanu11.png',
#   './dataset/cropped/keanu/keanu12.png',
#   './dataset/cropped/keanu/keanu13.png',
#   './dataset/cropped/keanu/keanu14.png',
#   './dataset/cropped/keanu/keanu15.png',
#   './dataset/cropped/keanu/keanu16.png',
#   './dataset/cropped/keanu/keanu17.png',
#   './dataset/cropped/keanu/keanu18.png',
#   './dataset/cropped/keanu/keanu19.png',
#   './dataset/cropped/keanu/keanu20.png',
#   './dataset/cropped/keanu/keanu21.png',
#   './dataset/cropped/keanu/keanu22.png',
#   './dataset/cropped/keanu/keanu23.png',
#   './dataset/cropped/keanu/keanu24.png',
#   './dataset/cropped/keanu/keanu25.png',
#   './dataset/cropped/keanu/keanu26.png',
#   './dataset/cropped/keanu/keanu27.png',
#   './dataset/cropped/keanu/keanu28.png',
#   './dataset/cropped/keanu/keanu29.png',
#   './dataset/cropped/keanu/keanu30.png',
#   './dataset/cropped/keanu/keanu31.png',
#   './dataset/cropped/keanu/keanu32.png',
#   './dataset/cropped/keanu/keanu33.png',
#   './dataset/cropped/keanu/keanu34.png',
#   './dataset/cropped/keanu/keanu35.png',
#   './dataset/cropped/keanu/keanu36.png',
#   './dataset/cropped/keanu/keanu37.png',
#   './dataset/cropped/keanu/keanu38.png',
#   './dataset/cropped/keanu/keanu39.png',
#   './dataset/cropped/keanu/keanu40.png',
#   './dataset/cropped/keanu/keanu41.png',
#   './dataset/cropped/keanu/keanu42.png',
#   './dataset/cropped/keanu/keanu43.png',
#   './dataset/cropped/keanu/keanu44.png',
#   './dataset/cropped/keanu/keanu45.png',
#   './dataset/cropped/keanu/keanu46.png',
#   './dataset/cropped/keanu/keanu47.png',
#   './dataset/cropped/keanu/keanu48.png',
#   './dataset/cropped/keanu/keanu49.png'],
#  'Raina': ['./dataset/cropped/Raina/Raina1.png',
#   './dataset/cropped/Raina/Raina2.png',
#   './dataset/cropped/Raina/Raina3.png',
#   './dataset/cropped/Raina/Raina4.png',
#   './dataset/cropped/Raina/Raina5.png',
#   './dataset/cropped/Raina/Raina6.png',
#   './dataset/cropped/Raina/Raina7.png',
#   './dataset/cropped/Raina/Raina8.png',
#   './dataset/cropped/Raina/Raina9.png',
#   './dataset/cropped/Raina/Raina10.png',
#   './dataset/cropped/Raina/Raina11.png',
#   './dataset/cropped/Raina/Raina12.png',
#   './dataset/cropped/Raina/Raina13.png',
#   './dataset/cropped/Raina/Raina14.png',
#   './dataset/cropped/Raina/Raina15.png',
#   './dataset/cropped/Raina/Raina16.png',
#   './dataset/cropped/Raina/Raina17.png',
#   './dataset/cropped/Raina/Raina18.png',
#   './dataset/cropped/Raina/Raina19.png',
#   './dataset/cropped/Raina/Raina20.png',
#   './dataset/cropped/Raina/Raina21.png',
#   './dataset/cropped/Raina/Raina22.png',
#   './dataset/cropped/Raina/Raina23.png',
#   './dataset/cropped/Raina/Raina24.png',
#   './dataset/cropped/Raina/Raina25.png',
#   './dataset/cropped/Raina/Raina26.png',
#   './dataset/cropped/Raina/Raina27.png',
#   './dataset/cropped/Raina/Raina28.png',
#   './dataset/cropped/Raina/Raina29.png',
#   './dataset/cropped/Raina/Raina30.png',
#   './dataset/cropped/Raina/Raina31.png',
#   './dataset/cropped/Raina/Raina32.png',
#   './dataset/cropped/Raina/Raina33.png',
#   './dataset/cropped/Raina/Raina34.png',
#   './dataset/cropped/Raina/Raina35.png',
#   './dataset/cropped/Raina/Raina36.png',
#   './dataset/cropped/Raina/Raina37.png',
#   './dataset/cropped/Raina/Raina38.png',
#   './dataset/cropped/Raina/Raina39.png',
#   './dataset/cropped/Raina/Raina40.png',
#   './dataset/cropped/Raina/Raina41.png',
#   './dataset/cropped/Raina/Raina42.png',
#   './dataset/cropped/Raina/Raina43.png',
#   './dataset/cropped/Raina/Raina44.png',
#   './dataset/cropped/Raina/Raina45.png',
#   './dataset/cropped/Raina/Raina46.png',
#   './dataset/cropped/Raina/Raina47.png',
#   './dataset/cropped/Raina/Raina48.png'],
#  'Ronaldo': ['./dataset/cropped/Ronaldo/Ronaldo1.png',
#   './dataset/cropped/Ronaldo/Ronaldo2.png',
#   './dataset/cropped/Ronaldo/Ronaldo3.png',
#   './dataset/cropped/Ronaldo/Ronaldo4.png',
#   './dataset/cropped/Ronaldo/Ronaldo5.png',
#   './dataset/cropped/Ronaldo/Ronaldo6.png',
#   './dataset/cropped/Ronaldo/Ronaldo7.png',
#   './dataset/cropped/Ronaldo/Ronaldo8.png',
#   './dataset/cropped/Ronaldo/Ronaldo9.png',
#   './dataset/cropped/Ronaldo/Ronaldo10.png',
#   './dataset/cropped/Ronaldo/Ronaldo11.png',
#   './dataset/cropped/Ronaldo/Ronaldo12.png',
#   './dataset/cropped/Ronaldo/Ronaldo13.png',
#   './dataset/cropped/Ronaldo/Ronaldo14.png',
#   './dataset/cropped/Ronaldo/Ronaldo15.png',
#   './dataset/cropped/Ronaldo/Ronaldo16.png',
#   './dataset/cropped/Ronaldo/Ronaldo17.png',
#   './dataset/cropped/Ronaldo/Ronaldo18.png',
#   './dataset/cropped/Ronaldo/Ronaldo19.png',
#   './dataset/cropped/Ronaldo/Ronaldo20.png',
#   './dataset/cropped/Ronaldo/Ronaldo21.png',
#   './dataset/cropped/Ronaldo/Ronaldo22.png',
#   './dataset/cropped/Ronaldo/Ronaldo23.png',
#   './dataset/cropped/Ronaldo/Ronaldo24.png',
#   './dataset/cropped/Ronaldo/Ronaldo25.png',
#   './dataset/cropped/Ronaldo/Ronaldo26.png',
#   './dataset/cropped/Ronaldo/Ronaldo27.png',
#   './dataset/cropped/Ronaldo/Ronaldo28.png',
#   './dataset/cropped/Ronaldo/Ronaldo29.png',
#   './dataset/cropped/Ronaldo/Ronaldo30.png',
#   './dataset/cropped/Ronaldo/Ronaldo31.png',
#   './dataset/cropped/Ronaldo/Ronaldo32.png',
#   './dataset/cropped/Ronaldo/Ronaldo33.png',
#   './dataset/cropped/Ronaldo/Ronaldo34.png',
#   './dataset/cropped/Ronaldo/Ronaldo35.png',
#   './dataset/cropped/Ronaldo/Ronaldo36.png',
#   './dataset/cropped/Ronaldo/Ronaldo37.png',
#   './dataset/cropped/Ronaldo/Ronaldo38.png',
#   './dataset/cropped/Ronaldo/Ronaldo39.png',
#   './dataset/cropped/Ronaldo/Ronaldo40.png',
#   './dataset/cropped/Ronaldo/Ronaldo41.png',
#   './dataset/cropped/Ronaldo/Ronaldo42.png',
#   './dataset/cropped/Ronaldo/Ronaldo43.png',
#   './dataset/cropped/Ronaldo/Ronaldo44.png',
#   './dataset/cropped/Ronaldo/Ronaldo45.png',
#   './dataset/cropped/Ronaldo/Ronaldo46.png',
#   './dataset/cropped/Ronaldo/Ronaldo47.png',
#   './dataset/cropped/Ronaldo/Ronaldo48.png',
#   './dataset/cropped/Ronaldo/Ronaldo49.png',
#   './dataset/cropped/Ronaldo/Ronaldo50.png',
#   './dataset/cropped/Ronaldo/Ronaldo51.png',
#   './dataset/cropped/Ronaldo/Ronaldo52.png',
#   './dataset/cropped/Ronaldo/Ronaldo53.png',
#   './dataset/cropped/Ronaldo/Ronaldo54.png',
#   './dataset/cropped/Ronaldo/Ronaldo55.png',
#   './dataset/cropped/Ronaldo/Ronaldo56.png',
#   './dataset/cropped/Ronaldo/Ronaldo57.png',
#   './dataset/cropped/Ronaldo/Ronaldo58.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'bale': 0, 'gadot': 1, 'keanu': 2, 'Raina': 3, 'Ronaldo': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X)
# Out:
# 286

# %%
32*32*3+32*32
# Out:
# 4096

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[0],
#        [2],
#        [2],
#        ...,
#        [0],
#        [0],
#        [4]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (286, 4096)

# %%
X[0]
# Out:
# array([0., 2., 2., ..., 0., 0., 4.])

# %%
y[0]
# Out:
# 0

# %%
#Training a Model begins

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7916666666666666

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.83      0.62        12
#            1       0.87      0.72      0.79        18
#            2       0.91      0.83      0.87        12
#            3       1.00      0.82      0.90        17
#            4       0.83      0.77      0.80        13
#
#     accuracy                           0.79        72
#    macro avg       0.82      0.80      0.80        72
# weighted avg       0.84      0.79      0.80        72

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.738206
# 1        random_forest    0.546622
# 2  logistic_regression    0.770986
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8611111111111112

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6388888888888888

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8194444444444444

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 8,  0,  1,  0,  3],
#        [ 1, 16,  0,  0,  1],
#        [ 0,  0, 11,  0,  1],
#        [ 0,  0,  0, 16,  1],
#        [ 1,  0,  1,  0, 11]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'bale': 0, 'gadot': 1, 'keanu': 2, 'Raina': 3, 'Ronaldo': 4}

# %%
#Save Model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\swaminathan\appdata\local\programs\python\python310\lib\site-packages (1.1.0)
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\Swaminathan\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ['saved_model.pkl']

# %%
#Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
